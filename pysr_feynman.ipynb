# %%
import numpy as np
import pandas as pd
from pysr import PySRRegressor
import matplotlib.pyplot as plt
import math

# %%
def generate_x(num_points, num_vars, variables, equation_row):
    X = np.zeros((num_points, num_vars))

    for i in range(1, num_vars):
        var_name = equation_row[f'v{i}_name']
        var_low = equation_row[f'v{i}_low']
        var_high = equation_row[f'v{i}_high']
        variables[var_name] = np.random.uniform(var_low, var_high, num_points)
        X[:, i-1] = variables[var_name]

    np_funcs = {func: getattr(np, func) for func in dir(np) if callable(getattr(np, func))}
    np_consts = {const: getattr(np, const) for const in dir(np) if not callable(getattr(np, const))}
    
    np_funcs = {
        'sin': np.sin, 'cos': np.cos, 'tan': np.tan,
        'exp': np.exp, 'log': np.log, 'ln': np.log,  # ln as alias for log
        'sqrt': np.sqrt, 'abs': np.abs,
        'pi': np.pi, 'e': np.e,
        'arcsin': np.arcsin, 'arccos': np.arccos, 'arctan': np.arctan,
        'tanh': np.tanh,
    }

    # Combine all namespaces
    eval_namespace = {**np_funcs, **np_consts, **variables}

    return X, variables, eval_namespace

# %%
def load_equations(filename):
    return pd.read_csv(filename)

def generate_data(equation_row, num_points=100):
    formula = equation_row['Formula']
    num_vars = int(equation_row['# variables'])

    variables = {}
    
    try:
        X, variables, eval_namespace = generate_x(num_points, num_vars,variables, equation_row)
        y = eval(formula, eval_namespace)
    except Exception as e:
        X, variables, eval_namespace = generate_x(num_points, num_vars + 1, variables, equation_row)
        y = eval(formula, eval_namespace)

    print(variables.keys())
    return X, y

def run_regression(equation_row):
    X, y = generate_data(equation_row)

    model = PySRRegressor(
        niterations=100,
        binary_operators=["+", "*", "/", "-"],
        unary_operators=["exp", "sqrt"],
        populations=20,
        ncycles_per_iteration=500,
        maxsize=20,
        verbosity=0,
        temp_equation_file=True,
    )

    model.fit(X, y)

    best_equation = model.sympy()
    print(f"Best equation: {best_equation}")

    y_pred = model.predict(X)

    # calculate MSE
    mse = np.mean((y - y_pred) ** 2)
    print(f"MSE: {mse}")
    return mse

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
equations = load_equations('FeynmanEquations.csv')
run_regression(equations.iloc[80])
# Out:
# dict_keys(['n_rho', 'mom', 'B', 'kb', 'T'])
# Best equation: x0*(x1 - sqrt(x3*x4/x2)) + x0
# MSE: 0.4749685941841237
# np.float64(0.4749685941841237)

# %%
mse_val = np.zeros(100)
equations = load_equations('FeynmanEquations.csv')
for i in range (0, 100):
    print(i)
    mse_val[i] = run_regression(equations.iloc[i])

print(f"Mean MSE: {np.mean(mse_val)}")
# Out:
# 0
# dict_keys(['theta'])
# Best equation: 0.3989423/sqrt(exp(x0**2))
# MSE: 3.0436772707041675e-17
# 1
# dict_keys(['sigma', 'theta'])
# Best equation: 0.10873686*(-2.2759373)/x0 + 1.1796887*0.65652645/(x0*exp(x1*0.47027144/x0))
# MSE: 1.2380603075487244e-05
# 2
# dict_keys(['sigma', 'theta', 'theta1'])
# Best equation: -x3 + 0.40459424/(x0 + 0.64080584/(x0/((-x1 + x2)*(-x1 + x2)) - 1*0.100057624))
# MSE: 1.338116072117309e-05
# 3
# dict_keys(['x1', 'x2', 'y1', 'y2'])
# Best equation: sqrt((-x2 + x3)**2 + exp((x0 - 1.8423289)/x1))
# MSE: 0.22870739598479697
# 4
# dict_keys(['m1', 'm2', 'G', 'x1', 'x2', 'y1', 'y2', 'z1', 'z2'])
# Best equation: x0*x1*x2*sqrt(x8)*(x4 + x6)/(x3*x5*x7)
# MSE: 0.00035511302349568966
# 5
# dict_keys(['m_0', 'v', 'c'])
# Best equation: x0*x1/(x2*(((-x1*x1 + x1 + x2 + x2)/x1))) + x0
# MSE: 7.809551450294396e-05
# 6
# dict_keys(['x1', 'x2', 'x3', 'y1', 'y2', 'y3'])
# Best equation: x0*x3 + x1*x4 + x2*x5
# MSE: 0.0
# 7
# dict_keys(['mu', 'Nn'])
# Best equation: x0*x1
# MSE: 0.0
# 8
# dict_keys(['q1', 'q2', 'epsilon', 'r'])
# Best equation: 0.07957746663088*x0*x1/(x2*x3**2) - sqrt(x4)
# MSE: 3.593675974505582e-17
# 9
# dict_keys(['q1', 'epsilon', 'r'])
# Best equation: 0.035238937*2.2582257*x0/(x2*x1*x2)
# MSE: 2.9389788944478443e-19
# 10
# dict_keys(['q2', 'Ef'])
# Best equation: x0*x1
# MSE: 0.0
# 11
# dict_keys(['q', 'Ef', 'B', 'v', 'theta'])
# Best equation: x0*x1 + (3.11827493 - x4)*(x0*x2*sqrt(x3) + x3)
# MSE: 27.922305283115765
# 12
# dict_keys(['m', 'v', 'u', 'w'])
# Best equation: x0*(x1 + x2 + x3 - 3.7026255)/0.35035938
# MSE: 10.138073254648827
# 13
# dict_keys(['m1', 'm2', 'r1', 'r2', 'G'])
# Best equation: x0*x1*x4/((x3/(((x2 - x3)/x2))))
# MSE: 2.036946444542171e-30
# 14
# dict_keys(['m', 'g', 'z'])
# Best equation: x0*x1*x2 + x3
# MSE: 0.0
# 15
# dict_keys(['k_spring', 'x'])
# Best equation: 0.5*x0*x1*x1
# MSE: 2.9691984915420238e-30
# 16
# dict_keys(['x', 'u', 'c', 't'])
# Best equation: x0 - x3*(x1 - 1*0.015527132) + (x0 - x1)/exp(x2/x1)
# MSE: 0.0012570175200881202
# 17
# dict_keys(['x', 'c', 'u', 't'])
# Best equation: x3 - (x0 - x3 + 0.5804048)/(0.7240559*(x1*x1))
# MSE: 0.0008575246672854399
# 18
# dict_keys(['m_0', 'v', 'c'])
# Best equation: x0*x1 + 1.03448610464816*x0/(x2*(-x1 + exp(sqrt(x2)/x1)))
# MSE: 0.0005814440025461108
# 19
# dict_keys(['c', 'v', 'u'])
# Best equation: x0 - (x0 - x2)/((x0 + x1*x2/x0)/(x0 - x1))
# MSE: 8.492580682769955e-32
# 20
# dict_keys(['m1', 'm2', 'r1', 'r2'])
# Best equation: (x2 + x3)/1.9798868 - 0.03526895
# MSE: 0.062458299906247426
# 21
# dict_keys(['r', 'F', 'theta'])
# Best equation: x1*x2*(3.3827868 - x2)*(sqrt(x0) - 0.29275116*x2) - 1.9114509
# MSE: 2.1117740060631593
# 22
# dict_keys(['m', 'r', 'v', 'theta'])
# Best equation: x0*x1*x2*(-x3 + sqrt(x3 - 0.990819) + 1.7081198) + 0.9829433
# MSE: 17.659012757280887
# 23
# dict_keys(['m', 'omega', 'omega_0', 'x'])
# Best equation: x0*x3*x3*(x1 - (1.8523095 - x2)) + 0.1774606
# MSE: 0.7801232366667166
# 24
# dict_keys(['q', 'C'])
# Best equation: x0/x1
# MSE: 0.0
# 25
# dict_keys(['n', 'theta2'])
# Best equation: x0*(x0 + 4.8274956)*2.6331859*(x1/(exp(x1) + 2.6331859) - 1*0.12591974)/1.0495046
# MSE: 0.0005586723115591118
# 26
# dict_keys(['d1', 'd2', 'n'])
# Best equation: x1/(x2 + x1/x0)
# MSE: 8.67438846952011e-33
# 27
# dict_keys(['omega', 'c'])
# Best equation: x0/x1
# MSE: 0.0
# 28
# dict_keys(['x1', 'x2', 'theta1', 'theta2'])
# Best equation: x0 - (-1)*0.0227228*exp(x1)
# MSE: 2.3208745766051546
# 29
# dict_keys(['Int_0', 'theta', 'n'])
# Best equation: x0*1.9535246/x1
# MSE: 3.4894971794348226
# 30
# dict_keys(['lambd', 'd', 'n'])
# Best equation: x0/(x1*x2 - 0.9416779*(sqrt(x0) - 0.87037873)/(x2*(x1 - 0.51317924))) - x3
# MSE: 1.9396572772236743e-07
# 31
# dict_keys(['q', 'a', 'epsilon', 'c'])
# Best equation: x1**2*(x0/sqrt(x3) - 1.5032163)*exp(-x3)/(x2*x3)
# MSE: 0.009288294265222765
# 32
# dict_keys(['epsilon', 'c', 'Ef', 'r', 'omega', 'omega_0'])
# Best equation: -x4 + (x0*x1 + x0)*exp(x4*(sqrt(x2) + sqrt(x3)) - x5)
# MSE: 0.7067832311205219
# 33
# dict_keys(['q', 'v', 'B', 'p'])
# Best equation: x0*x1*x2/x3
# MSE: 0.0
# 34
# dict_keys(['c', 'v', 'omega_0'])
# Best equation: x2 + x2/(((x0 - x1)/x1))
# MSE: 1.41501924874019e-31
# 35
# dict_keys(['c', 'v', 'omega_0'])
# Best equation: x2*exp(x1/(x0 - (x1 - 0.6556995)/x0))
# MSE: 2.3596792575589668e-05
# 36
# dict_keys(['omega', 'h'])
# Best equation: -(-0.15915494)*x0*x1 + x2
# MSE: 9.905816018488388e-16
# 37
# dict_keys(['I1', 'I2', 'delta'])
# Best equation: (x0 + x1)*(x2*(-(-0.36498994)*x2 - 2.281025) + 3.6237116) + 0.10200051
# MSE: 0.10647508617036977
# 38
# dict_keys(['m', 'q', 'h', 'epsilon'])
# Best equation: x2*0.31830987*x2*x3/(x0*x1*x1)
# MSE: 8.68161151131093e-15
# 39
# dict_keys(['pr', 'V'])
# Best equation: x0*x1*1.5
# MSE: 0.0
# 40
# dict_keys(['gamma', 'pr', 'V'])
# Best equation: x1*x2/(x0 - exp(x3))
# MSE: 3.1998170468027292e-31
# 41
# dict_keys(['n', 'T', 'V', 'kb'])
# Best equation: x0*x1*x3/x2
# MSE: 1.3790274699394812e-30
# 42
# dict_keys(['n_0', 'm', 'x', 'T', 'g', 'kb'])
# Best equation: sqrt(x0**2*exp(-2*x1*x2*x4/(x3*x5)))
# MSE: 8.593623700785222e-33
# 43
# dict_keys(['omega', 'T', 'h', 'kb', 'c'])
# Best equation: 0.103575853105344*x0*(x0*x1*x3 - x2)/(x4*(x4 + 0.030225884))
# MSE: 0.009489949550751517
# 44
# dict_keys(['mu_drift', 'q', 'Volt', 'd'])
# Best equation: x0*x1*x2/x3
# MSE: 0.0
# 45
# dict_keys(['mob', 'T', 'kb'])
# Best equation: x0*x1*x2
# MSE: 7.528198226137268e-30
# 46
# dict_keys(['gamma', 'kb', 'A', 'v'])
# Best equation: x1*x3/(x2*(x0 - exp(x4)))
# MSE: 1.3318961123404367e-31
# 47
# dict_keys(['n', 'kb', 'T', 'V1', 'V2'])
# Best equation: 0.965043425024039*x0*x1*x2*(-x3 + x4)/sqrt(x3*x4)
# MSE: 0.18999783739175735
# 48
# dict_keys(['gamma', 'pr', 'rho'])
# Best equation: sqrt(x0*x1/x2)
# MSE: 0.0
# 49
# dict_keys(['m', 'v', 'c'])
# Best equation: x0*x1*x1*0.55355406 + x0*x2*x2
# MSE: 0.11809876609125014
# 50
# dict_keys(['x1', 'omega', 't', 'alpha'])
# Best equation: x3*(x1 - x1/x2)
# MSE: 2.69381705114878
# 51
# dict_keys(['kappa', 'T1', 'T2', 'A', 'd'])
# Best equation: x0*x3*(-x1 + x2)/x4
# MSE: 2.5500323576907806e-31
# 52
# dict_keys(['Pwr', 'r'])
# Best equation: 0.07957747*x0/(x1*x1)
# MSE: 1.664737994047512e-18
# 53
# dict_keys(['q', 'epsilon', 'r'])
# Best equation: 0.079579234*(x0 - x1 + x1 - x3 - 1*5.5570854e-5)/(x1*x2)
# MSE: 2.6961475906298647e-13
# 54
# dict_keys(['epsilon', 'p_d', 'theta', 'r'])
# Best equation: x1*(x2 - 1.5759495)*(-0.05488586)/(x3*0.8633025*x3*x0)
# MSE: 4.423225951062232e-06
# 55
# dict_keys(['epsilon', 'p_d', 'r', 'x', 'y', 'z'])
# Best equation: 0.853158533662778*sqrt(x1)*sqrt(x3)*x5/(x0*(-sqrt(x4) + exp(x2**2)))
# MSE: 0.000797762562994166
# 56
# dict_keys(['epsilon', 'p_d', 'theta', 'r'])
# Best equation: (1.4653001 - x2)/(x0*x3*x3*((x3/x1))*exp(x2))
# MSE: 6.497315890925551e-05
# 57
# dict_keys(['q', 'epsilon', 'd'])
# Best equation: 0.047746483/(x1*((x2/(x0*x0))))
# MSE: 2.990345255753894e-20
# 58
# dict_keys(['epsilon', 'Ef'])
# Best equation: x1*x1*0.5*x0 - 0.907269 - 1*0.3390755 + 1.2463446
# MSE: 1.000000017243764e-14
# 59
# dict_keys(['sigma_den', 'epsilon', 'chi'])
# Best equation: x0/(x1*x2 + x1)
# MSE: 2.338560434972201e-33
# 60
# dict_keys(['q', 'Ef', 'm', 'omega_0', 'omega'])
# Best equation: x0*x1/(x2*(x3*x3 - x4*x4))
# MSE: 0.0
# 61
# dict_keys(['n_0', 'kb', 'T', 'theta', 'p_d', 'Ef'])
# Best equation: 1.0070517*(x0 - x0*x4/(x2*(x1*1.2802304/(x5*(x3 - 1*1.5619134)))))
# MSE: 0.039094958119356996
# 62
# dict_keys(['n_rho', 'p_d', 'Ef', 'kb', 'T'])
# Best equation: (x0 - 1.4001611*(-7.812778e-7))*x1*x1*0.33333325/((x3/x2)*x4) - 3.8441976e-7
# MSE: 4.626915265700426e-13
# 63
# dict_keys(['n', 'alpha', 'epsilon', 'Ef'])
# Best equation: 1.08277540122823*x0*x1*x2*x3*sqrt(x0*x1 + 0.744740626652999)
# MSE: 9.288484408412645e-05
# 64
# dict_keys(['n', 'alpha'])
# Best equation: 1.08642850662158*sqrt(exp(1.6856883*x0*x1) - 0.152369342858942)
# MSE: 1.72365535006076e-07
# 65
# dict_keys(['epsilon', 'c', 'I', 'r'])
# Best equation: -x4 + 0.159154948121135*x2/(x0*x1**2*x3)
# MSE: 8.758375158501247e-19
# 66
# dict_keys(['rho_c_0', 'v', 'c'])
# Best equation: x0*x3 + x0/sqrt(exp(x1*(-x1 - 0.0874943)/(x2*(x2 - 0.08979497))))
# MSE: 2.8198570406654778e-05
# 67
# dict_keys(['rho_c_0', 'v', 'c'])
# Best equation: x0*x1*sqrt(exp(x1**2/(x2*(x2 - 0.5035788))))
# MSE: 0.00015335777103274532
# 68
# dict_keys(['mom', 'B', 'theta'])
# Best equation: x0*sqrt(x1)*exp(x2)/(exp(exp(x2)/x2**2) - 0.7910513) - x0
# MSE: 1.6292639896048393
# 69
# dict_keys(['p_d', 'Ef', 'theta'])
# Best equation: x0*x1*(4.1009364 + (-0.035625566*exp(x2) - 4.758047)/sqrt(x2)) - 0.369798655
# MSE: 0.6055729583358016
# 70
# dict_keys(['q', 'epsilon', 'r', 'v', 'c'])
# Best equation: x0*(exp(0.498856141587933*exp(-x4/x3)) - 0.9064678)/(x1*x2)
# MSE: 1.76770105116623e-06
# 71
# dict_keys(['omega', 'c', 'd'])
# Best equation: x0/x1 + x3 - x1/(x0*(x2 - 1*1.2664967))
# MSE: 0.00010242570583705887
# 72
# dict_keys(['epsilon', 'c', 'Ef'])
# Best equation: x0*x1*x2*x2
# MSE: 1.5200560782703676e-28
# 73
# dict_keys(['epsilon', 'Ef'])
# Best equation: x0*x1*x1
# MSE: 5.776433978480859e-30
# 74
# dict_keys(['q', 'v', 'r'])
# Best equation: x0*x1*0.15915494/x2 - x3
# MSE: 1.8739089234168909e-16
# 75
# dict_keys(['q', 'v', 'r'])
# Best equation: x0*x1*x2*0.5
# MSE: 0.0
# 76
# dict_keys(['g_', 'q', 'B', 'm'])
# Best equation: x1*x2/(x3*((2.0000012/x0)))
# MSE: 2.1676536941287128e-11
# 77
# dict_keys(['q', 'h', 'm'])
# Best equation: (x0 + x0)*0.039788738*x1/x2 - 1*4.179899e-9
# MSE: 3.286393872477599e-16
# 78
# dict_keys(['g_', 'h', 'Jz', 'mom', 'B'])
# Best equation: x3*x2*6.283185*x0*x4/x1
# MSE: 2.6470770106583556e-10
# 79
# dict_keys(['n_0', 'kb', 'T', 'mom', 'B'])
# Best equation: 1.4936278*x0/(exp(1.1124456997158*x3*x4/(x1*x2)) + 1.6693048)
# MSE: 0.00018749048967295077
# 80
# dict_keys(['n_rho', 'mom', 'B', 'kb', 'T'])
# Best equation: x0*(x1 - sqrt(x3*x4/x2) + 1.0370084)
# MSE: 0.6329234226238291
# 81
# dict_keys(['mom', 'H', 'kb', 'T', 'alpha', 'epsilon', 'c', 'M'])
# Best equation: -0.013704915 + (x1 + x7*2.12554*x4/(x5*exp(x6)))/(x2*((x3/x0)))
# MSE: 0.0035923360884364836
# 82
# dict_keys(['mom', 'B', 'chi'])
# Best equation: x0*(x1*x2 + x1)
# MSE: 2.3011072605296916e-29
# 83
# dict_keys(['Y', 'A', 'd', 'x'])
# Best equation: x0*x1*x3/x2
# MSE: 0.0
# 84
# dict_keys(['Y', 'sigma'])
# Best equation: x0*0.5/(x1 + exp(x2))
# MSE: 0.0
# 85
# dict_keys(['h', 'omega', 'kb', 'T'])
# Best equation: -1*0.4707714 + x2*x3*6.27686/(x0*x1)
# MSE: 0.0004665127815291935
# 86
# dict_keys(['h', 'omega', 'kb', 'T'])
# Best equation: x2*x3 - 0.068571925*(x0*x1 + 0.71940976)
# MSE: 0.003501288058661055
# 87
# dict_keys(['mom', 'B', 'h'])
# Best equation: 12.566371*x0*x1/x2
# MSE: 2.7418590636415864e-12
# 88
# dict_keys(['E_n', 't', 'h'])
# Best equation: x2/(x0 + sqrt(exp(x2)))
# MSE: 0.1269011472227697
# 89
# dict_keys(['p_d', 'Ef', 't', 'h', 'omega', 'omega_0'])
# Best equation: (x1 + x2)*exp(x0/sqrt(x3)) - exp(-x4 + x5)
# MSE: 118.03900117254523
# 90
# dict_keys(['mom', 'Bx', 'By', 'Bz'])
# Best equation: x0*(x1 + x2 + x3)/1.7064532 + 0.5137306
# MSE: 0.377323691825927
# 91
# dict_keys(['n', 'h'])
# Best equation: 0.9254789*x0*0.17197037*x1 + x2
# MSE: 3.658314153324368e-15
# 92
# dict_keys(['E_n', 'd', 'k', 'h'])
# Best equation: 12.56637*x1*x1*x2/((x3/x0))
# MSE: 1.5407141463396237e-09
# 93
# dict_keys(['I_0', 'q', 'Volt', 'kb', 'T'])
# Best equation: x0*x2*1.2199134/(-0.31320095*x2 + x3*x4/x1) - 0.18838325
# MSE: 0.021714642846580756
# 94
# dict_keys(['U', 'k', 'd'])
# Best equation: x0*1.848688
# MSE: 17.75621861393948
# 95
# dict_keys(['h', 'E_n', 'd'])
# Best equation: x0*x0*0.012665148/(x1*x2*x2)
# MSE: 7.711328773760003e-21
# 96
# dict_keys(['alpha', 'n', 'd'])
# Best equation: 6.2831855*x0/(x1*x2)
# MSE: 1.6166606374885368e-14
# 97
# dict_keys(['beta', 'alpha', 'theta'])
# Best equation: x0*x1*(x2 - 1*1.5247155)*(x2 - 1*4.7129445)/2.672089 + x0
# MSE: 0.19358717476151205
# 98
# dict_keys(['m', 'q', 'h', 'n', 'epsilon'])
# Best equation: -0.49092403*x0*(x1 - 1*1.3956572)/(0.5670375*x3*(-x1 + x2*x4 + x3))
# MSE: 0.01512207399728506
# 99
# dict_keys(['rho_c_0', 'q', 'A_vec', 'm'])
# Best equation: x0*x1*x2*(-1.0)/x3
# MSE: 0.0
# Mean MSE: 2.0799623106598393
